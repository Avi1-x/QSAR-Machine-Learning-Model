# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor
# Out:
# /Users/Avi/opt/miniconda3/envs/ddp/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_csv('Beta_Secretase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %%
X.shape
# Out:
# (7062, 881)

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (7062, 160)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [02:56<00:00,  4.20s/it]
# 100%|██████████| 42/42 [00:00<00:00, 210215.71it/s]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                          Adjusted R-Squared  \
# Model
# DecisionTreeRegressor                                  0.86
# ExtraTreeRegressor                                     0.86
# ExtraTreesRegressor                                    0.86
# GaussianProcessRegressor                               0.86
# RandomForestRegressor                                  0.81
# BaggingRegressor                                       0.79
# XGBRegressor                                           0.77
# MLPRegressor                                           0.72
# HistGradientBoostingRegressor                          0.59
# LGBMRegressor                                          0.59
# KNeighborsRegressor                                    0.58
# SVR                                                    0.53
# NuSVR                                                  0.52
# GradientBoostingRegressor                              0.40
# Ridge                                                  0.33
# RidgeCV                                                0.33
# ElasticNetCV                                           0.33
# LassoCV                                                0.33
# SGDRegressor                                           0.32
# BayesianRidge                                          0.32
# LinearSVR                                              0.31
# TransformedTargetRegressor                             0.30
# LinearRegression                                       0.30
# PoissonRegressor                                       0.29
# LassoLarsIC                                            0.25
# GeneralizedLinearRegressor                             0.24
# TweedieRegressor                                       0.24
# GammaRegressor                                         0.24
# OrthogonalMatchingPursuit                              0.24
# OrthogonalMatchingPursuitCV                            0.24
# LassoLarsCV                                            0.22
# LarsCV                                                 0.20
# AdaBoostRegressor                                      0.16
# Lars                                                   0.01
# Lasso                                                 -0.03
# ElasticNet                                            -0.03
# DummyRegressor                                        -0.03
# LassoLars                                             -0.03
# PassiveAggressiveRegressor                            -0.07
# KernelRidge                                          -22.28
# RANSACRegressor               -1708398819348875764039680.00
#
#                                                   R-Squared             RMSE  \
# Model
# DecisionTreeRegressor                                  0.86             0.52
# ExtraTreeRegressor                                     0.86             0.52
# ExtraTreesRegressor                                    0.86             0.52
# GaussianProcessRegressor                               0.86             0.52
# RandomForestRegressor                                  0.82             0.60
# BaggingRegressor                                       0.79             0.63
# XGBRegressor                                           0.77             0.66
# MLPRegressor                                           0.73             0.72
# HistGradientBoostingRegressor                          0.60             0.87
# LGBMRegressor                                          0.60             0.87
# KNeighborsRegressor                                    0.59             0.89
# SVR                                                    0.54             0.94
# NuSVR                                                  0.54             0.94
# GradientBoostingRegressor                              0.42             1.06
# Ridge                                                  0.35             1.12
# RidgeCV                                                0.35             1.12
# ElasticNetCV                                           0.35             1.12
# LassoCV                                                0.35             1.12
# SGDRegressor                                           0.34             1.13
# BayesianRidge                                          0.34             1.13
# LinearSVR                                              0.33             1.14
# TransformedTargetRegressor                             0.32             1.14
# LinearRegression                                       0.32             1.14
# PoissonRegressor                                       0.31             1.15
# LassoLarsIC                                            0.27             1.18
# GeneralizedLinearRegressor                             0.27             1.19
# TweedieRegressor                                       0.27             1.19
# GammaRegressor                                         0.26             1.19
# OrthogonalMatchingPursuit                              0.26             1.19
# OrthogonalMatchingPursuitCV                            0.26             1.19
# LassoLarsCV                                            0.24             1.20
# LarsCV                                                 0.22             1.22
# AdaBoostRegressor                                      0.18             1.25
# Lars                                                   0.04             1.36
# Lasso                                                  0.00             1.39
# ElasticNet                                             0.00             1.39
# DummyRegressor                                         0.00             1.39
# LassoLars                                              0.00             1.39
# PassiveAggressiveRegressor                            -0.04             1.41
# KernelRidge                                          -21.62             6.59
# RANSACRegressor               -1660002252228510921785344.00 1785351221388.61
#
#                                Time Taken
# Model
# DecisionTreeRegressor                0.14
# ExtraTreeRegressor                   0.13
# ExtraTreesRegressor                  8.45
# GaussianProcessRegressor            51.51
# RandomForestRegressor                6.13
# BaggingRegressor                     0.82
# XGBRegressor                         1.89
# MLPRegressor                        11.15
# HistGradientBoostingRegressor        2.56
# LGBMRegressor                        0.45
# KNeighborsRegressor                  6.75
# SVR                                 13.44
# NuSVR                                9.31
# GradientBoostingRegressor            3.01
# Ridge                                0.10
# RidgeCV                              0.44
# ElasticNetCV                         3.92
# LassoCV                              3.85
# SGDRegressor                         0.15
# BayesianRidge                        0.49
# LinearSVR                            1.25
# TransformedTargetRegressor           0.22
# LinearRegression                     0.21
# PoissonRegressor                     0.15
# LassoLarsIC                          0.22
# GeneralizedLinearRegressor           0.10
# TweedieRegressor                     0.10
# GammaRegressor                       0.10
# OrthogonalMatchingPursuit            0.10
# OrthogonalMatchingPursuitCV          0.29
# LassoLarsCV                          0.44
# LarsCV                               0.75
# AdaBoostRegressor                    1.52
# Lars                                 0.14
# Lasso                                0.06
# ElasticNet                           0.06
# DummyRegressor                       0.05
# LassoLars                            0.10
# PassiveAggressiveRegressor           0.09
# KernelRidge                         44.26
# RANSACRegressor                      0.84

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
# Empty DataFrame
# Columns: [Adjusted R-Squared, R-Squared, RMSE, Time Taken]
# Index: []

# %% [markdown]
# ## **Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
